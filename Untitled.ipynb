# %%
import pandas as pd
import numpy as np
pd.read_excel('Pytanie_5.xls')
df = pd.read_excel('Pytanie_5.xls')
# Out:
#    Twój wiek? narzędzie niezbędne do wykonywania pracy i właściwe warunki bhp  \
# 0   24-39 lat                                       bardzo ważne
# 1   40-55 lat                                       bardzo ważne
# 2   24-39 lat                                       raczej ważne
# 3   24-39 lat                                       bardzo ważne
# 4   18-23 lat                                       bardzo ważne
# ..        ...                                                ...
# 89  24-39 lat                                       bardzo ważne
# 90  18-23 lat                                       bardzo ważne
# 91  24-39 lat                                       raczej ważne
# 92  24-39 lat                                       bardzo ważne
# 93  40-55 lat                                       bardzo ważne
#
#    dopasowane do potrzeb warunki socjalne  \
# 0                            raczej ważne
# 1                            bardzo ważne
# ...

# %%
print(list(df.columns))
# Out:
# ['Twój wiek?', 'narzędzie niezbędne do wykonywania pracy i właściwe warunki bhp', 'dopasowane do potrzeb warunki socjalne', 'możliwość awansu i przejrzyste jego warunki', 'satysfakcjonujące wynagrodzenie i przejrzyste zasady przydzielania podwyżek', 'szansę na rozwój osobisty', 'możliwość udziału w szkoleniach rozwijających kwalifikacje', 'bezpieczeństwo zatrudnienia (stałą umowę o pracę)', 'samodzielność w pracy', 'dopasowany do Twoich potrzeb system motywacyjny', 'zachowanie równowagi pomiędzy pracą a życiem osobistym (work life balance)', 'przejrzyste systemy oceny pracy', 'brak dyskryminowania i faworyzowania wybranych pracowników', 'regularne otrzymywanie informacji zwrotnych dotyczących oceny jakości pracy', 'szacunek i poszanowanie godności ze strony przełożonych i współpracowników', 'dbałośc o klimat sprzyjający zadowoleniu z pracy']
